# %%
from linearmodels import PanelOLS

# %%
# %store -r new_df

# %%
digital = new_df
digital.describe()
# Out:
#        Access Electricity   Cellular %  Fixed broadband %    GDP pcp PPP  \
# count         3572.000000  3924.000000        3904.000000    3915.000000
# mean            75.070279    57.219870         541.798200   14459.653033
# std             33.478636    52.491984         977.152958   17900.726057
# min              0.000000     0.000000           0.000000       0.000000
# 25%             49.973213     5.686211           0.000000    2509.293321
# 50%             96.100000    47.621538          17.010518    7700.877635
# 75%            100.000000   100.603396         583.959213   19947.832275
# max            100.000000   332.090701        6173.884929  140037.115597
#
#         Landline %  Secure Servers  Urbanisation  internet_users
# count  3916.000000     3896.000000   3948.000000     3889.000000
# mean     18.929920     3349.633291     55.447683       23.656629
# std      18.984450    25668.442665     24.154125       27.131545
# ...

# %%
digital.reset_index(inplace = True)
digital.set_index(['country', 'date'], inplace = True)
#digital.drop(['level_0', 'index'], axis = 1, inplace = True)

# %%
digital.head()
# Out:
#                           Access Electricity  Cellular %  Fixed broadband %  \
# country             date
# Afghanistan         1996            0.000000    0.000000                0.0
# Albania             1996          100.000000    0.068841                0.0
# Algeria             1996           95.352905    0.039202                0.0
# Angola              1996           44.342175    0.026486                0.0
# Antigua and Barbuda 1996           85.741631    1.850666                0.0
#
#                            GDP pcp PPP  Landline %  Secure Servers  \
# country             date
# Afghanistan         1996      0.000000    0.157478             0.0
# Albania             1996   3109.183498    1.911080             0.0
# Algeria             1996   7059.883533    4.282570             0.0
# Angola              1996   2380.132838    0.422625             0.0
# Antigua and Barbuda 1996  12693.314580   39.860488             0.0
#
# ...

# %%
exog = digital.columns[:-1]

# %%
mod = PanelOLS(digital['internet_users'], digital[exog], entity_effects = True, )
res = mod.fit(cov_type='clustered', cluster_entity = True)
# Out:
# /home/antonia/.conda/envs/my_root/lib/python3.6/site-packages/linearmodels/utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)

# %%
res
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:         internet_users   R-squared:                        0.8551
# Estimator:                   PanelOLS   R-squared (Between):              0.9453
# No. Observations:                3414   R-squared (Within):               0.8551
# Date:                Sun, Oct 08 2017   R-squared (Overall):              0.9213
# Time:                        00:56:00   Log-likelihood                -1.127e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      2714.2
# Entities:                         188   P-value                           0.0000
# Avg Obs:                       18.160   Distribution:                  F(7,3219)
# Min Obs:                       6.0000
# Max Obs:                       19.000   F-statistic (robust):             316.48
#                                         P-value                           0.0000
# ...

# %%
mod = PanelOLS(digital['internet_users'], digital[exog])
res = mod.fit(cov_type='clustered', cluster_entity = True)
# Out:
# /home/antonia/.conda/envs/my_root/lib/python3.6/site-packages/linearmodels/utility.py:476: MissingValueWarning:
# Inputs contain missing values. Dropping rows with missing observations.
#   warnings.warn(missing_value_warning_msg, MissingValueWarning)

# %%
res
# Out:
#                           PanelOLS Estimation Summary
# ...
# Dep. Variable:         internet_users   R-squared:                        0.9320
# Estimator:                   PanelOLS   R-squared (Between):              0.9628
# No. Observations:                3414   R-squared (Within):               0.8482
# Date:                Sun, Oct 08 2017   R-squared (Overall):              0.9320
# Time:                        01:02:59   Log-likelihood                 -1.22e+04
# Cov. Estimator:             Clustered
#                                         F-statistic:                      6671.9
# Entities:                         188   P-value                           0.0000
# Avg Obs:                       18.160   Distribution:                  F(7,3407)
# Min Obs:                       6.0000
# Max Obs:                       19.000   F-statistic (robust):             624.80
#                                         P-value                           0.0000
# ...

# %%
#which panel model should I use? Check woolridge etc. for some guidance
